# %%
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt

import laminarFlow2

# %%
# Identifictation of the initial 
length = 25
radius = 1/12
serConcentration = 1
trypConcentration = 1


model = laminarFlow2.LaminarFlow(length, radius, serConcentration, trypConcentration, 1000)
# Out:
# [  1.00000000e-04   1.00000000e-02   1.00000000e-01   2.50000000e-01
#    5.00000000e-01   7.50000000e-01   1.00000000e+00   2.00000000e+00
#    4.00000000e+00   6.00000000e+00   8.00000000e+00   1.00000000e+01
#    2.50000000e+01   5.00000000e+01   7.50000000e+01   1.00000000e+02
#    1.00000000e+03   1.00000000e+04]
# [  1.00000000e-04   1.00000000e-02   1.00000000e-01   2.50000000e-01
#    5.00000000e-01   7.50000000e-01   1.00000000e+00   2.00000000e+00
#    4.00000000e+00   6.00000000e+00   8.00000000e+00   1.00000000e+01
#    2.50000000e+01   5.00000000e+01   7.50000000e+01   1.00000000e+02
#    1.00000000e+03   1.00000000e+04]

# %%
plt.plot(model.lengths, model.serGraetz)
plt.plot(model.lengths, model.trypGraetz)

# %%
plt.plot(model.lengths, model.serConcentration)
plt.plot(model.lengths, model.trypConcentration)
