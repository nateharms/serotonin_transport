# %%
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt

import laminarFlow2

# %%
# Identifictation of the initial 
length = 25
radius = 1/12
serConcentration = 1
trypConcentration = 1


model = laminarFlow2.LaminarFlow(length, radius, serConcentration, trypConcentration, 200)

# %%
plt.plot(model.lengths, model.serGraetz)
plt.plot(model.lengths, model.trypGraetz)
